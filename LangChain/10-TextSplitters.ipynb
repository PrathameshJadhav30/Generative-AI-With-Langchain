# %%
! pip install langchain langchain-text-splitters langchain-community tiktoken
# Out:
# Requirement already satisfied: langchain in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (0.3.30)
# Requirement already satisfied: langchain-text-splitters in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (0.3.11)
# Requirement already satisfied: langchain-community in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (0.3.31)
# Requirement already satisfied: tiktoken in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (0.5.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.85 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain) (0.3.86)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain) (0.4.37)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain) (2.0.38)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain-community) (3.11.12)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain-community) (2.11.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (4.16.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (23.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (0.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.85->langchain) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (1.3.1)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("sample.txt")
documents = loader.load()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_16568\419954856.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %% [markdown]
# # CharacterTextSplitter

# %%
from langchain_text_splitters import CharacterTextSplitter

splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size=100,
    chunk_overlap=20
)

chunks = splitter.split_documents(documents)

print(chunks)
# Out:
# [Document(metadata={'source': 'sample.txt'}, page_content='LangChain is a framework for building LLM-powered applications.'), Document(metadata={'source': 'sample.txt'}, page_content='It supports prompts, chains, agents, RAG, and much more.')]

# %%
for i, chunk in enumerate(chunks, start=1):
    print(f"Chunk {i}")
    print(chunk.page_content)
    print("-" * 40)
# Out:
# Chunk 1
# LangChain is a framework for building LLM-powered applications.
# ----------------------------------------
# Chunk 2
# It supports prompts, chains, agents, RAG, and much more.
# ----------------------------------------

# %% [markdown]
# # RecursiveCharacterTextSplitter

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=50
)

chunks = splitter.split_documents(documents)

print(chunks)
# Out:
# [Document(metadata={'source': 'sample.txt'}, page_content='LangChain is a framework for building LLM-powered applications.\n\nIt supports prompts, chains, agents, RAG, and much more.')]

# %%
for chunk in chunks:
    print(chunk.page_content)
    print("=" * 50)
# Out:
# LangChain is a framework for building LLM-powered applications.
#
# It supports prompts, chains, agents, RAG, and much more.
# ==================================================

# %% [markdown]
# # Split Plain Text

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text = """
Artificial Intelligence is transforming industries.
Machine Learning is a subset of AI.
Deep Learning is a subset of Machine Learning.
"""

splitter = RecursiveCharacterTextSplitter(
    chunk_size=50,
    chunk_overlap=10
)

chunks = splitter.split_text(text)

print(chunks)
# Out:
# ['Artificial Intelligence is transforming', 'industries.', 'Machine Learning is a subset of AI.', 'Deep Learning is a subset of Machine Learning.']

# %% [markdown]
# # TokenTextSplitter

# %%
from langchain_text_splitters import TokenTextSplitter

splitter = TokenTextSplitter(
    chunk_size=50,
    chunk_overlap=10
)

chunks = splitter.split_documents(documents)

print(chunks)
# Out:
# [Document(metadata={'source': 'sample.txt'}, page_content='LangChain is a framework for building LLM-powered applications.\n\nIt supports prompts, chains, agents, RAG, and much more.')]

# %% [markdown]
# # MarkdownHeaderTextSplitter

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter

headers = [
    ("#", "Heading 1"),
    ("##", "Heading 2")
]

splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on=headers
)

with open("notes.md", "r", encoding="utf-8") as file:
    markdown = file.read()

chunks = splitter.split_text(markdown)

print(chunks)
# Out:
# []

# %% [markdown]
# # HTMLHeaderTextSplitter

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from bs4) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4->bs4) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hp\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4->bs4) (4.16.0)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

headers = [
    ("h1", "Heading1"),
    ("h2", "Heading2")
]

splitter = HTMLHeaderTextSplitter(
    headers_to_split_on=headers
)

chunks = splitter.split_text("""
<h1>LangChain</h1>
<p>Introduction</p>

<h2>Models</h2>
<p>Chat Models</p>
""")

print(chunks)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 12
#       8 splitter = HTMLHeaderTextSplitter(
#       9     headers_to_split_on=headers
#      10 )
#      11
# ---> 12 chunks = splitter.split_text("""
#      13 <h1>LangChain</h1>
#      14 <p>Introduction</p>
#      15
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_text_splitters\html.py:186, in HTMLHeaderTextSplitter.split_text(self, text)
#     174 def split_text(self, text: str) -> list[Document]:
#     175     """Split the given text into a list of `Document` objects.
#     176
#     177     Args:
#    (...)    184             `metadata` that maps the header hierarchy to their corresponding titles.
#     185     """
# --> 186     return self.split_text_from_file(StringIO(text))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_text_splitters\html.py:243, in HTMLHeaderTextSplitter.split_text_from_file(self, file)
#     241 else:
#     242     html_content = file.read()
# --> 243 return list(self._generate_documents(html_content))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_text_splitters\html.py:265, in HTMLHeaderTextSplitter._generate_documents(self, html_content)
#     261 if not _HAS_BS4:
#     262     msg = (
#     263         "Unable to import BeautifulSoup. Please install via `pip install bs4`."
#     264     )
# --> 265     raise ImportError(msg)
#     267 soup = BeautifulSoup(html_content, "html.parser")
#     268 body = soup.body or soup
#
# ImportError: Unable to import BeautifulSoup. Please install via `pip install bs4`.

# %% [markdown]
# # Chunk Size Comparison

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

for size in [100, 200, 500]:

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=size,
        chunk_overlap=20
    )

    chunks = splitter.split_documents(documents)

    print(f"Chunk Size: {size}")
    print("Number of Chunks:", len(chunks))
    print("-" * 40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       6         chunk_size=size,
#       7         chunk_overlap=20
#       8     )
#       9
# ---> 10     chunks = splitter.split_documents(documents)
#      11
#      12     print(f"Chunk Size: {size}")
#      13     print("Number of Chunks:", len(chunks))
#
# NameError: name 'documents' is not defined
