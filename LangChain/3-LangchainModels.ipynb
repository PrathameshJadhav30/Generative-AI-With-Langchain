# %% [markdown]
# # LLMs (Large Language Models)

# %%
from dotenv import load_dotenv
from langchain_openai import OpenAI

load_dotenv()

llm = OpenAI(
    model="gpt-3.5-turbo-instruct",
    temperature=0
)

response = llm.invoke("What is Artificial Intelligence?")

print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[1], line 11
#       7     model="gpt-3.5-turbo-instruct",
#       8     temperature=0
#       9 )
#      10
# ---> 11 response = llm.invoke("What is Artificial Intelligence?")
#      12
#      13 print(response)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\llms.py:384, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     373 @override
#     374 def invoke(
#     375     self,
#    (...)    380     **kwargs: Any,
#     381 ) -> str:
#     382     config = ensure_config(config)
#     383     return (
# --> 384         self.generate_prompt(
#     385             [self._convert_input(input)],
#     386             stop=stop,
#     387             callbacks=config.get("callbacks"),
#     388             tags=config.get("tags"),
#     389             metadata=config.get("metadata"),
#     390             run_name=config.get("run_name"),
#     391             run_id=config.pop("run_id", None),
#     392             **kwargs,
#     393         )
#     394         .generations[0][0]
#     395         .text
#     396     )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\llms.py:801, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     792 @override
#     793 def generate_prompt(
#     794     self,
#    (...)    798     **kwargs: Any,
#     799 ) -> LLMResult:
#     800     prompt_strings = [p.to_string() for p in prompts]
# --> 801     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\llms.py:1031, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1012 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#    1013     run_managers = [
#    1014         callback_manager.on_llm_start(
#    1015             self._serialized,
#    (...)   1029         )
#    1030     ]
# -> 1031     return self._generate_helper(
#    1032         prompts,
#    1033         stop,
#    1034         run_managers,
#    1035         new_arg_supported=bool(new_arg_supported),
#    1036         **kwargs,
#    1037     )
#    1038 if len(missing_prompts) > 0:
#    1039     run_managers = [
#    1040         callback_managers[idx].on_llm_start(
#    1041             self._serialized,
#    (...)   1048         for idx in missing_prompt_idxs
#    1049     ]
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\llms.py:827, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     816 def _generate_helper(
#     817     self,
#     818     prompts: list[str],
#    (...)    823     **kwargs: Any,
#     824 ) -> LLMResult:
#     825     try:
#     826         output = (
# --> 827             self._generate(
#     828                 prompts,
#     829                 stop=stop,
#     830                 # TODO: support multiple run managers
#     831                 run_manager=run_managers[0] if run_managers else None,
#     832                 **kwargs,
#     833             )
#     834             if new_arg_supported
#     835             else self._generate(prompts, stop=stop)
#     836         )
#     837     except BaseException as e:
#     838         for run_manager in run_managers:
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\llms\base.py:510, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     494     choices.append(
#     495         {
#     496             "text": generation.text,
#    (...)    507         }
#     508     )
#     509 else:
# --> 510     response = self.client.create(prompt=_prompts, **params)
#     511     if not isinstance(response, dict):
#     512         # V1 client returns the response in an PyDantic object instead of
#     513         # dict. For the transition period, we deep convert it to dict.
#     514         response = response.model_dump()
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\resources\completions.py:554, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     525 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     526 def create(
#     527     self,
#    (...)    552     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     553 ) -> Completion | Stream[Completion]:
# --> 554     return self._post(
#     555         "/completions",
#     556         body=maybe_transform(
#     557             {
#     558                 "model": model,
#     559                 "prompt": prompt,
#     560                 "best_of": best_of,
#     561                 "echo": echo,
#     562                 "frequency_penalty": frequency_penalty,
#     563                 "logit_bias": logit_bias,
#     564                 "logprobs": logprobs,
#     565                 "max_tokens": max_tokens,
#     566                 "n": n,
#     567                 "presence_penalty": presence_penalty,
#     568                 "seed": seed,
#     569                 "stop": stop,
#     570                 "stream": stream,
#     571                 "stream_options": stream_options,
#     572                 "suffix": suffix,
#     573                 "temperature": temperature,
#     574                 "top_p": top_p,
#     575                 "user": user,
#     576             },
#     577             completion_create_params.CompletionCreateParamsStreaming
#     578             if stream
#     579             else completion_create_params.CompletionCreateParamsNonStreaming,
#     580         ),
#     581         options=make_request_options(
#     582             extra_headers=extra_headers,
#     583             extra_query=extra_query,
#     584             extra_body=extra_body,
#     585             timeout=timeout,
#     586             security={"bearer_auth": True},
#     587         ),
#     588         cast_to=Completion,
#     589         stream=stream or False,
#     590         stream_cls=Stream[Completion],
#     591     )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# # Another Example

# %%
question = "Explain Machine Learning in one sentence."

response = llm.invoke(question)

print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 question = "Explain Machine Learning in one sentence."
#       2
# ----> 3 response = llm.invoke(question)
#       4
#       5 print(response)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\llms.py:384, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     373 @override
#     374 def invoke(
#     375     self,
#    (...)    380     **kwargs: Any,
#     381 ) -> str:
#     382     config = ensure_config(config)
#     383     return (
# --> 384         self.generate_prompt(
#     385             [self._convert_input(input)],
#     386             stop=stop,
#     387             callbacks=config.get("callbacks"),
#     388             tags=config.get("tags"),
#     389             metadata=config.get("metadata"),
#     390             run_name=config.get("run_name"),
#     391             run_id=config.pop("run_id", None),
#     392             **kwargs,
#     393         )
#     394         .generations[0][0]
#     395         .text
#     396     )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\llms.py:801, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     792 @override
#     793 def generate_prompt(
#     794     self,
#    (...)    798     **kwargs: Any,
#     799 ) -> LLMResult:
#     800     prompt_strings = [p.to_string() for p in prompts]
# --> 801     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\llms.py:1031, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1012 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#    1013     run_managers = [
#    1014         callback_manager.on_llm_start(
#    1015             self._serialized,
#    (...)   1029         )
#    1030     ]
# -> 1031     return self._generate_helper(
#    1032         prompts,
#    1033         stop,
#    1034         run_managers,
#    1035         new_arg_supported=bool(new_arg_supported),
#    1036         **kwargs,
#    1037     )
#    1038 if len(missing_prompts) > 0:
#    1039     run_managers = [
#    1040         callback_managers[idx].on_llm_start(
#    1041             self._serialized,
#    (...)   1048         for idx in missing_prompt_idxs
#    1049     ]
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\llms.py:827, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     816 def _generate_helper(
#     817     self,
#     818     prompts: list[str],
#    (...)    823     **kwargs: Any,
#     824 ) -> LLMResult:
#     825     try:
#     826         output = (
# --> 827             self._generate(
#     828                 prompts,
#     829                 stop=stop,
#     830                 # TODO: support multiple run managers
#     831                 run_manager=run_managers[0] if run_managers else None,
#     832                 **kwargs,
#     833             )
#     834             if new_arg_supported
#     835             else self._generate(prompts, stop=stop)
#     836         )
#     837     except BaseException as e:
#     838         for run_manager in run_managers:
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\llms\base.py:510, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     494     choices.append(
#     495         {
#     496             "text": generation.text,
#    (...)    507         }
#     508     )
#     509 else:
# --> 510     response = self.client.create(prompt=_prompts, **params)
#     511     if not isinstance(response, dict):
#     512         # V1 client returns the response in an PyDantic object instead of
#     513         # dict. For the transition period, we deep convert it to dict.
#     514         response = response.model_dump()
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\resources\completions.py:554, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     525 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     526 def create(
#     527     self,
#    (...)    552     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     553 ) -> Completion | Stream[Completion]:
# --> 554     return self._post(
#     555         "/completions",
#     556         body=maybe_transform(
#     557             {
#     558                 "model": model,
#     559                 "prompt": prompt,
#     560                 "best_of": best_of,
#     561                 "echo": echo,
#     562                 "frequency_penalty": frequency_penalty,
#     563                 "logit_bias": logit_bias,
#     564                 "logprobs": logprobs,
#     565                 "max_tokens": max_tokens,
#     566                 "n": n,
#     567                 "presence_penalty": presence_penalty,
#     568                 "seed": seed,
#     569                 "stop": stop,
#     570                 "stream": stream,
#     571                 "stream_options": stream_options,
#     572                 "suffix": suffix,
#     573                 "temperature": temperature,
#     574                 "top_p": top_p,
#     575                 "user": user,
#     576             },
#     577             completion_create_params.CompletionCreateParamsStreaming
#     578             if stream
#     579             else completion_create_params.CompletionCreateParamsNonStreaming,
#     580         ),
#     581         options=make_request_options(
#     582             extra_headers=extra_headers,
#     583             extra_query=extra_query,
#     584             extra_body=extra_body,
#     585             timeout=timeout,
#     586             security={"bearer_auth": True},
#     587         ),
#     588         cast_to=Completion,
#     589         stream=stream or False,
#     590         stream_cls=Stream[Completion],
#     591     )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# # Chat Models

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()

model = init_chat_model(
    "gpt-5",
    model_provider="openai"
)

response = model.invoke(
    "What is LangChain?"
)

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 11
#       7     "gpt-5",
#       8     model_provider="openai"
#       9 )
#      10
# ---> 11 response = model.invoke(
#      12     "What is LangChain?"
#      13 )
#      14
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1738, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1736     _handle_openai_bad_request(e)
#    1737 except openai.APIError as e:
# -> 1738     _handle_openai_api_error(e)
#    1739 except Exception as e:
#    1740     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1733, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1726         return _construct_lc_result_from_responses_api(
#    1727             response,
#    1728             schema=original_schema_obj,
#    1729             metadata=generation_info,
#    1730             output_version=self.output_version,
#    1731         )
#    1732     else:
# -> 1733         raw_response = self.client.with_raw_response.create(**payload)
#    1734         response = raw_response.parse()
#    1735 except openai.BadRequestError as e:
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1281, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1232 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1233 def create(
#    1234     self,
#    (...)   1278     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1279 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1280     validate_response_format(response_format)
# -> 1281     return self._post(
#    1282         "/chat/completions",
#    1283         body=maybe_transform(
#    1284             {
#    1285                 "messages": messages,
#    1286                 "model": model,
#    1287                 "audio": audio,
#    1288                 "frequency_penalty": frequency_penalty,
#    1289                 "function_call": function_call,
#    1290                 "functions": functions,
#    1291                 "logit_bias": logit_bias,
#    1292                 "logprobs": logprobs,
#    1293                 "max_completion_tokens": max_completion_tokens,
#    1294                 "max_tokens": max_tokens,
#    1295                 "metadata": metadata,
#    1296                 "modalities": modalities,
#    1297                 "moderation": moderation,
#    1298                 "n": n,
#    1299                 "parallel_tool_calls": parallel_tool_calls,
#    1300                 "prediction": prediction,
#    1301                 "presence_penalty": presence_penalty,
#    1302                 "prompt_cache_key": prompt_cache_key,
#    1303                 "prompt_cache_options": prompt_cache_options,
#    1304                 "prompt_cache_retention": prompt_cache_retention,
#    1305                 "reasoning_effort": reasoning_effort,
#    1306                 "response_format": response_format,
#    1307                 "safety_identifier": safety_identifier,
#    1308                 "seed": seed,
#    1309                 "service_tier": service_tier,
#    1310                 "stop": stop,
#    1311                 "store": store,
#    1312                 "stream": stream,
#    1313                 "stream_options": stream_options,
#    1314                 "temperature": temperature,
#    1315                 "tool_choice": tool_choice,
#    1316                 "tools": tools,
#    1317                 "top_logprobs": top_logprobs,
#    1318                 "top_p": top_p,
#    1319                 "user": user,
#    1320                 "verbosity": verbosity,
#    1321                 "web_search_options": web_search_options,
#    1322             },
#    1323             completion_create_params.CompletionCreateParamsStreaming
#    1324             if stream
#    1325             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1326         ),
#    1327         options=make_request_options(
#    1328             extra_headers=extra_headers,
#    1329             extra_query=extra_query,
#    1330             extra_body=extra_body,
#    1331             timeout=timeout,
#    1332             security={"bearer_auth": True},
#    1333         ),
#    1334         cast_to=ChatCompletion,
#    1335         stream=stream or False,
#    1336         stream_cls=Stream[ChatCompletionChunk],
#    1337     )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# # Chat Model with Multiple Messages

# %%
from langchain_core.messages import (
    SystemMessage,
    HumanMessage
)

messages = [
    SystemMessage(
        content="You are a helpful AI tutor."
    ),
    HumanMessage(
        content="Explain Deep Learning."
    )
]

response = model.invoke(messages)

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 15
#      11         content="Explain Deep Learning."
#      12     )
#      13 ]
#      14
# ---> 15 response = model.invoke(messages)
#      16
#      17 print(response.content)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1738, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1736     _handle_openai_bad_request(e)
#    1737 except openai.APIError as e:
# -> 1738     _handle_openai_api_error(e)
#    1739 except Exception as e:
#    1740     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1733, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1726         return _construct_lc_result_from_responses_api(
#    1727             response,
#    1728             schema=original_schema_obj,
#    1729             metadata=generation_info,
#    1730             output_version=self.output_version,
#    1731         )
#    1732     else:
# -> 1733         raw_response = self.client.with_raw_response.create(**payload)
#    1734         response = raw_response.parse()
#    1735 except openai.BadRequestError as e:
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1281, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1232 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1233 def create(
#    1234     self,
#    (...)   1278     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1279 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1280     validate_response_format(response_format)
# -> 1281     return self._post(
#    1282         "/chat/completions",
#    1283         body=maybe_transform(
#    1284             {
#    1285                 "messages": messages,
#    1286                 "model": model,
#    1287                 "audio": audio,
#    1288                 "frequency_penalty": frequency_penalty,
#    1289                 "function_call": function_call,
#    1290                 "functions": functions,
#    1291                 "logit_bias": logit_bias,
#    1292                 "logprobs": logprobs,
#    1293                 "max_completion_tokens": max_completion_tokens,
#    1294                 "max_tokens": max_tokens,
#    1295                 "metadata": metadata,
#    1296                 "modalities": modalities,
#    1297                 "moderation": moderation,
#    1298                 "n": n,
#    1299                 "parallel_tool_calls": parallel_tool_calls,
#    1300                 "prediction": prediction,
#    1301                 "presence_penalty": presence_penalty,
#    1302                 "prompt_cache_key": prompt_cache_key,
#    1303                 "prompt_cache_options": prompt_cache_options,
#    1304                 "prompt_cache_retention": prompt_cache_retention,
#    1305                 "reasoning_effort": reasoning_effort,
#    1306                 "response_format": response_format,
#    1307                 "safety_identifier": safety_identifier,
#    1308                 "seed": seed,
#    1309                 "service_tier": service_tier,
#    1310                 "stop": stop,
#    1311                 "store": store,
#    1312                 "stream": stream,
#    1313                 "stream_options": stream_options,
#    1314                 "temperature": temperature,
#    1315                 "tool_choice": tool_choice,
#    1316                 "tools": tools,
#    1317                 "top_logprobs": top_logprobs,
#    1318                 "top_p": top_p,
#    1319                 "user": user,
#    1320                 "verbosity": verbosity,
#    1321                 "web_search_options": web_search_options,
#    1322             },
#    1323             completion_create_params.CompletionCreateParamsStreaming
#    1324             if stream
#    1325             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1326         ),
#    1327         options=make_request_options(
#    1328             extra_headers=extra_headers,
#    1329             extra_query=extra_query,
#    1330             extra_body=extra_body,
#    1331             timeout=timeout,
#    1332             security={"bearer_auth": True},
#    1333         ),
#    1334         cast_to=ChatCompletion,
#    1335         stream=stream or False,
#    1336         stream_cls=Stream[ChatCompletionChunk],
#    1337     )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# # Embedding Models

# %%
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings

load_dotenv()

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small"
)

vector = embeddings.embed_query(
    "What is Artificial Intelligence?"
)

print(vector)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 10
#       6 embeddings = OpenAIEmbeddings(
#       7     model="text-embedding-3-small"
#       8 )
#       9
# ---> 10 vector = embeddings.embed_query(
#      11     "What is Artificial Intelligence?"
#      12 )
#      13
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:805, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     795 """Call out to OpenAI's embedding endpoint for embedding query text.
#     796
#     797 Args:
#    (...)    802     Embedding for the text.
#     803 """
#     804 self._ensure_sync_client_available()
# --> 805 return self.embed_documents([text], **kwargs)[0]
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:622, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     620 # Make API call with this batch
#     621 batch_tokens = tokens[i:batch_end]
# --> 622 response = self.client.create(input=batch_tokens, **client_kwargs)
#     623 if not isinstance(response, dict):
#     624     response = response.model_dump()
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\resources\embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# # Check Embedding Size

# %%
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings

load_dotenv()

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small"
)

vector = embeddings.embed_query(
    "Hello LangChain"
)

print(len(vector))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 10
#       6 embeddings = OpenAIEmbeddings(
#       7     model="text-embedding-3-small"
#       8 )
#       9
# ---> 10 vector = embeddings.embed_query(
#      11     "Hello LangChain"
#      12 )
#      13
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:805, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     795 """Call out to OpenAI's embedding endpoint for embedding query text.
#     796
#     797 Args:
#    (...)    802     Embedding for the text.
#     803 """
#     804 self._ensure_sync_client_available()
# --> 805 return self.embed_documents([text], **kwargs)[0]
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:622, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     620 # Make API call with this batch
#     621 batch_tokens = tokens[i:batch_end]
# --> 622 response = self.client.create(input=batch_tokens, **client_kwargs)
#     623 if not isinstance(response, dict):
#     624     response = response.model_dump()
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\resources\embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# # Embed Multiple Documents

# %%
documents = [
    "Artificial Intelligence",
    "Machine Learning",
    "Deep Learning"
]

vectors = embeddings.embed_documents(documents)

print(len(vectors))
print(len(vectors[0]))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 7
#       3     "Machine Learning",
#       4     "Deep Learning"
#       5 ]
#       6
# ----> 7 vectors = embeddings.embed_documents(documents)
#       8
#       9 print(len(vectors))
#      10 print(len(vectors[0]))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:622, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     620 # Make API call with this batch
#     621 batch_tokens = tokens[i:batch_end]
# --> 622 response = self.client.create(input=batch_tokens, **client_kwargs)
#     623 if not isinstance(response, dict):
#     624     response = response.model_dump()
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\resources\embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Generative AI With LangChain\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
